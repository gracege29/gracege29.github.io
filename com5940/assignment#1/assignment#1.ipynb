# %%
import pymysql.cursors
connection = pymysql.connect(host="localhost", 
                     user="root",   
                     passwd="root", 
                     db="bta",   
                     charset='utf8mb4',
                     cursorclass=pymysql.cursors.DictCursor)

# %%
with connection.cursor() as cursor:
        sql = "SELECT * FROM drinks"
        cursor.execute(sql)
        result = cursor.fetchall()
        dataset = []
        temp = {}
        i = 0
        for row in result:
            temp[i] = row
            dataset.append(temp[i])
            i = i + 1
        print('\n')
        print(dataset)
        print('\n')
# Out:
# [{'id': 1, 'name': '四季春茶', 'shop': '一点点', 'type': '纯茶', 'tea': '四季春茶', 'ingredients': None, 'describe': '不加配料，请于「找醇茶」订购，「找好茶」饮品默认为加免费配料售价。\r\n主要原料：四季春茶'}, {'id': 2, 'name': '布丁奶茶', 'shop': '一点点', 'type': '奶茶', 'tea': '红茶', 'ingredients': '植脂末,布丁', 'describe': '奶茶搭配布丁，滑顺入口。辅料：布丁、植脂末。\r\n主要原料：红茶'}, {'id': 3, 'name': '四季如意', 'shop': '一点点', 'type': '纯茶', 'tea': '四季春茶', 'ingredients': '燕麦', 'describe': '四季春搭配燕麦，健康好口感。辅料：燕麦。\r\n主要原料：四季春茶'}, {'id': 4, 'name': '四季奶青', 'shop': '一点点', 'type': '奶茶', 'tea': '四季春茶', 'ingredients': '植脂末', 'describe': '四季春茶搭配特选植脂末，经由黄金比例调制而成，香滑顺口。辅料：植脂末。\r\n主要原料：四季春茶'}, {'id': 5, 'name': '清香乌龙茶', 'shop': '一点点', 'type': '纯茶', 'tea': '乌龙茶', 'ingredients': None, 'describe': '乌龙茶味醇甘润，喉韵回甘十足。找醇茶系列饮品无法添加配料，需加配料请于「找好茶」订购!\r\n主要原料：乌龙茶'}, {'id': 6, 'name': '阿华田拿铁', 'shop': '一点点', 'type': '拿铁', 'tea': '阿华田', 'ingredients': '牛乳', 'describe': '拿铁系列饮品，外卖服务「一律不做渐层效果」!阿华田搭配牛乳，香甜可口。辅料：牛乳。\r\n主要原料：阿华田'}, {'id': 7, 'name': '咖啡冻奶茶', 'shop': '一点点', 'type': '奶茶', 'tea': '红茶', 'ingredie
# ...

# %%
import requests

headers = {
'Authorization': 'Bearer keyVPDmCemvZStnmu',
}

params = (
('view', 'Grid view'),
)
#Grid view 是在airtable左上角显示的视图。

r = requests.get('https://api.airtable.com/v0/app7TKGp6rF2j3lnR/%E9%80%89%E8%8C%B6?api_key=keyVPDmCemvZStnmu&sortField=_createdTime&sortDirection=desc', headers=headers, params=params)
dict = r.json()
dataset = []
name = []
shop = []
drinktype = []
for i in dict['records']:
     dict = i['fields']
     dataset.append(dict)
print(dataset)
print('\n')
for dicts in dataset:
    name.append(dicts.get('name'))
    shop.append(dicts.get('shop'))
    drinktype.append(dicts.get('drinktype'))
print(name)
# Out:
# [{'name': '霸气西柚', 'describe': '用茉莉毛尖做茶底，带有花香特有的香气。加入鲜榨西柚，果粒饱满，营养丰富。西柚糖分较少，搭配茶底清甜爽口，还有一丝回甘 主要原料：西柚', 'shop': ['rec5z8QDe2NrBZJ2L'], 'ingredients': ['rec3mfoL28tGkRFGR'], 'tea': ['recHPyve1rMHT82C3'], 'drinktype': '果茶'}, {'name': '青心乌龙（冷泡茶）', 'describe': '来自台湾阿里山的乌龙茶,作为正大名茶的特有品种,甘甜带果胶质和花香气,滋味清醇甘甜低温冷泡8小时,减少咖啡因释放,降低涩味。主要原料:乌龙茶', 'shop': ['rec5z8QDe2NrBZJ2L'], 'tea': ['rec0ZxTzENXjhm9vM'], 'drinktype': '纯茶'}, {'name': '冻顶乌龙（冷泡茶）', 'describe': '来自台湾阿里山的乌龙茶,醇厚回甘。低温冷泡8小时,减少咖啡因释放,降低涩味。主要原料:乌龙茶', 'shop': ['rec5z8QDe2NrBZJ2L'], 'tea': ['rec0ZxTzENXjhm9vM'], 'drinktype': '纯茶'}, {'name': '冻顶宝藏茶', 'describe': '奶油系列马上饮用口味更佳,外卖暂不上线;精选名优茶冻顶乌龙,加入特调鲜牛乳,喉韵甘醇且持久,搭配软糯Q弹的黑糖珍珠,芝士奶盖的加入,多重口感的丰富体验 主要原料:牛奶', 'shop': ['rec5z8QDe2NrBZJ2L'], 'ingredients': ['recHAvY5JZOs2YnXE', 'rec6BVtzzsAuDB5iY', 'recN4iNtPcAHFuauO', 'rec3HSdowXXVahezj'], 'tea': ['rec0ZxTzENXjhm9vM'], 'drinktype': '奶茶'}, {'name': '芝士茉莉毛尖', 'describe': '热饮为纸杯包装,茉莉花的香气和毛尖的清新融合,汤色清亮主要原料:其他', 'shop': ['rec5z8QDe2NrBZJ2L'], 'ingredients': ['rec3HSdow
# ...
